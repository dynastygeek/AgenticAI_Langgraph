# %%
print(" This is the model for generating, evaluating, and optimizing the tweet, using 3 different LLMs")
# Out:
#  This is the model for generating, evaluating, and optimizing the tweet, using 3 different LLMs
